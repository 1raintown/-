# %% [markdown]
# <h1 align=center><font size = 5> <center>文本分析与挖掘</center> </font></h1>
#
# <h2 align=center><font size = 4><center>期末综合作业</center></font></h2>
# <h2 align=center><font size = 2><center>浙江工业大学计算机科学与技术学院</center></font></h2>

# %% [markdown]
# # 使用SMOTE,、ADASYN降低类别不平衡影响

# %%
import jieba
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report
import unicodedata
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import re
import pandas_bokeh
from imblearn.over_sampling import SMOTE, ADASYN
import collections

# %%
np.set_printoptions(threshold=10000) #全显示

# %% [markdown]
# ### 1.预训练

# %% [markdown]
# #### a. 加载数据

# %%
x_train_data=pd.read_excel('警情数据集/X_train.xlsx')
x_test_data=pd.read_excel('警情数据集/X_test.xlsx')

y_train_data=pd.read_excel('警情数据集/y_train.xlsx')
y=y_train_data['最终反馈警情类别']
y_test_data=pd.read_excel('警情数据集/y_test.xlsx')
y_test=y_test_data['最终反馈警情类别']

x=x_train_data['报警内容']+'。'+x_train_data['出警情况（反馈内容）']
x_test=x_test_data['报警内容']+'。'+x_test_data['出警情况（反馈内容）']

# %%
title_mapping = {"求助": 0, "治安案件": 1, "纠纷": 2, "举报": 3, "其它报警": 4,"刑事案件":5}#将标签对应数值
y= y.map(title_mapping)#处理数据
y = y.fillna(0).values##将其余标签填充为0值
y_test= y_test.map(title_mapping)#处理数据
y_test = y_test.fillna(0).values##将其余标签填充为0值

#进行文本清洗
x_doc = x.apply(lambda x: re.sub("[0-9]+|年|月|日|时|分|、|。|，|：|:|[*]|（.*?）|{.*?}|[.*?]|【.*?】", "",x))
x_test_doc = x_test.apply(lambda x: re.sub("[0-9]+|年|月|日|时|分|、|。|，|：|:|[*]|（.*?）|{.*?}|[.*?]|【.*?】", "",x))

# %%
cut_docs = x_doc.apply(lambda x: jieba.cut(x)).values
#构建词汇表
vocab = set()

for doc in cut_docs:
    for word in doc:
        if word.strip():
                vocab.add(word.strip())
                
# 将词表写入本地vocab.txt文件
with open('clean_vocab.txt', 'w') as file:
    for word in  vocab:
        file.write(word)
        file.write('\n')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\DELL\AppData\Local\Temp\jieba.cache
# Loading model cost 0.563 seconds.
# Prefix dict has been built successfully.

# %%
#配置类
class Config():
    def __init__(self,embedding_dim, max_seq_len):
        self.embedding_dim = embedding_dim # 词向量维度
        self.max_seq_len = max_seq_len # 文章长度
        self.vocab_file = 'clean_vocab.txt' # 词汇表文件路径

#预处理类
class Preprocessor():
    def __init__(self, config):
        self.config = config
        # 初始化词和id的映射词典，预留0给padding字符，1给词表中未见过的词
        token2idx = {"[PAD]": 0, "[UNK]": 1} # {word：id}
        with open(config.vocab_file, 'r') as reader:
            for index, line in enumerate(reader):
                token = line.strip()
                token2idx[token] = index+2
                
        self.token2idx = token2idx
        
    def transform(self, text_list):
        # 文本分词，并将词转换成相应的id, 最后不同长度的文本padding长统一长度，后面补0
        idx_list = [[self.token2idx.get(word.strip(), self.token2idx['[UNK]']) for word in jieba.cut(text)] for text in text_list]
        idx_padding = pad_sequences(idx_list, self.config.max_seq_len, padding='post')
        
        return idx_padding

# %% [markdown]
# #### b.把每个句子/评论转成长度统一为 max_len=100 的向量，太长的截断，太短的后面补零。

# %%
config1 = Config(300,100)#词向量维度=300,句长为100
preprocessor1 = Preprocessor(config1)

# %%
x=preprocessor1.transform(x_doc)
x_test=preprocessor1.transform(x_test_doc)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\DELL\AppData\Local\Temp\jieba.cache
# Loading model cost 0.615 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# ### 查看原始数据

# %%
col=dict(collections.Counter(y))
map1 = {0:"求助", 1:"治安案件",2: "纠纷",3: "举报",4: "其它报警",5:"刑事案件"}
for k in list(col):
    col[map1[k]] = col.pop(k)
pd1=pd.DataFrame.from_dict(col, orient='index')
pd1.columns=['数量']

pandas_bokeh.output_notebook()
#在notebook中能显示可视化结果pandas_bokeh.output_notebook()#将fruits列设置为行索引df = pd.read_excel(fruits.xlsx')
pd1.plot_bokeh(kind='bar',
              
              ylabel='案件数量',xlabel='案件类型',
              title='数量',
              show_figure=True) #显示
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="02244b28-6bd4-47c7-b181-30ca14bb60b0" data-root-id="1038"></div>
# Figure(id='1038', ...)

# %% [markdown]
# ## 使用SMOTE进行上采样

# %% [markdown]
# ### (1)使得6个类别的比例近似为1

# %%
oversample = SMOTE()
X, Y = oversample.fit_resample(x, y)

# %%
new_y=dict(collections.Counter(Y))
for k in list(new_y):
    new_y[map1[k]] = new_y.pop(k)
pd2=pd.DataFrame.from_dict(new_y, orient='index')
pd2.columns=['数量']
pandas_bokeh.output_notebook()
#在notebook中能显示可视化结果pandas_bokeh.output_notebook()#将fruits列设置为行索引df = pd.read_excel(fruits.xlsx')
pd2.plot_bokeh(kind='bar',
              
              ylabel='案件数量',xlabel='案件类型',
              title='数量',
              show_figure=True) #显示
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1391">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e1661d48-9bd0-4f7a-8f88-95e4866d4710" data-root-id="1428"></div>
# Figure(id='1428', ...)

# %%
x_train,x_valid,y_train, y_valid = train_test_split(X,Y, test_size=0.2, random_state=42)

# %% [markdown]
# #### 设置模型并训练

# %% [markdown]
#  - a.设置 embedding 层输出维度 embed_dim=300；
#  - b.卷积层设置三种卷积核大小 kernel_size=[2,3,4]，每种大小用64 个卷积核，即 filters=64；
#  - c.倒数第二的全连接 dense 层输出 64 维，Relu 激活；
#  - d.最后一个输出二分类结果，1 个节点，sigmoid 激活。

# %%
class TextCNN(object):
    def __init__(self, config):
        self.config = config
        self.preprocessor = Preprocessor(config)
        self.class_name = {0:"求助" , 1:"治安案件", 2:"纠纷", 3:"举报",4: "其它报警",5:"刑事案件"}
    
    def build_model(self):
        # 模型架构搭建
        idx_input = tf.keras.layers.Input((self.config.max_seq_len,))
        input_embedding = tf.keras.layers.Embedding(len(self.preprocessor.token2idx),
                    self.config.embedding_dim,
                    input_length=self.config.max_seq_len,
                    mask_zero=True)(idx_input)
        convs = []
        for kernel_size in [2, 3, 4]:
            c = tf.keras.layers.Conv1D(64, kernel_size, activation='relu')(input_embedding)
            c = tf.keras.layers.GlobalMaxPooling1D()(c)
            convs.append(c)
        fea_cnn = tf.keras.layers.Concatenate()(convs)
        fea_cnn_dropout = tf.keras.layers.Dropout(rate=0.4)(fea_cnn)
        
        fea_dense = tf.keras.layers.Dense(64, activation='relu')(fea_cnn_dropout)
        output = tf.keras.layers.Dense(6, activation='softmax')(fea_dense)
        
        model = tf.keras.Model(inputs=idx_input, outputs=output)
        model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(lr = 0.001,decay =1e-2),
              metrics=['accuracy'])
        
        model.summary()
        
        self.model = model
    
    def fit(self, x_train, y_train, x_valid=None, y_valid=None, epochs=5, batch_size=128, callbacks=None, **kwargs):
        # 训练
        valid_data = None
        if x_valid is not None and y_valid is not None:
            valid_data = (x_valid, y_valid)

        self.history=self.model.fit(
            x=x_train,
            y=y_train,
            validation_data= valid_data,
            batch_size=batch_size,
            epochs=epochs,
            callbacks=callbacks,
            **kwargs
        )
        
    def evaluate(self, x_test, y_test):
        # 评估
        y_pred_probs = self.model.predict(x_test)
        y_pred = np.argmax(y_pred_probs, axis=-1)
        result = classification_report(y_test, y_pred, target_names=['求助','治安案件','纠纷','举报','其它报警','刑事案件'])
        print(result)
        
        
    def single_predict(self, text):
        # 预测
        test=re.sub("[0-9]+|年|月|日|时|分|、|：||:|[*]|（.*?）|{.*?}|[.*?]|【.*?】", "",text)
        input_idx = self.preprocessor.transform([text])
        predict_prob = self.model.predict(input_idx)[0]
        predict_label_id = np.argmax(predict_prob)
        
        predict_label_name = self.class_name[predict_label_id]
        predict_label_prob = predict_prob[predict_label_id]
        
        return predict_label_name, predict_label_prob
    
    def load_model(self, ckpt_file):
        self.build_model()
        self.model.load_weights(ckpt_file)

# %% [markdown]
# #### 打印模型参数

# %%
textcnn = TextCNN(config1)
textcnn.build_model()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 100, 300)     5198700     input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 99, 64)       38464       embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 98, 64)       57664       embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 97, 64)       76864       embedding_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_3 (GlobalM (None, 64)           0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_4 (GlobalM (None, 64)           0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_5 (GlobalM (None, 64)           0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 192)          0           global_max_pooling1d_3[0][0]
#                                                                  global_max_pooling1d_4[0][0]
#                                                                  global_max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 192)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           12352       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            390         dense_2[0][0]
# ==================================================================================================
# Total params: 5,384,434
# Trainable params: 5,384,434
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### 设置损失函数、epoch、优化器、学习率等超参数并训练模型。

# %%
# 定义early stop早停回调函数
patience = 10
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)

# 定义checkpoint回调函数
checkpoint_prefix = './clean_checkpoints_smote/textcnn_imdb_ckpt'
checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True,
    save_best_only=True)

# %%
textcnn.fit(x_train, y_train, x_valid, y_valid, epochs=50, callbacks=[early_stop, checkpoint_callback]) # 训练
# Out:
# Epoch 1/50
# 107/107 [==============================] - 7s 62ms/step - loss: 1.4306 - accuracy: 0.4154 - val_loss: 1.1511 - val_accuracy: 0.5273
# Epoch 2/50
# 107/107 [==============================] - 7s 62ms/step - loss: 1.0342 - accuracy: 0.6227 - val_loss: 1.0812 - val_accuracy: 0.5484
# Epoch 3/50
# 107/107 [==============================] - 7s 62ms/step - loss: 0.8571 - accuracy: 0.7406 - val_loss: 1.0519 - val_accuracy: 0.5595
# Epoch 4/50
# 107/107 [==============================] - 7s 62ms/step - loss: 0.7059 - accuracy: 0.8251 - val_loss: 1.0401 - val_accuracy: 0.5648
# Epoch 5/50
# 107/107 [==============================] - 7s 62ms/step - loss: 0.5828 - accuracy: 0.8711 - val_loss: 1.0392 - val_accuracy: 0.5595
# Epoch 6/50
# 107/107 [==============================] - 7s 65ms/step - loss: 0.4958 - accuracy: 0.8964 - val_loss: 1.0339 - val_accuracy: 0.5610
# Epoch 7/50
# 107/107 [==============================] - 8s 72ms/step - loss: 0.4223 - accuracy: 0.9179 - val_loss: 1.0334 - val_accuracy: 0.5657
# Epoch 8/50
# 107/107 [==============================] - 7s 62ms/step - loss: 0.3626 - accuracy: 0.9311 - val_loss: 1.0378 - val_accuracy: 0.5601
# Epoch 9/50
# 107/107 [==============================] - 6s 60ms/step - loss: 0.3208 - accuracy: 0.9385 - val_loss: 1.0390 - val_accuracy: 0.5610
# Epoch 10/50
# 107/107 [==============================] - 6s 61ms/step - loss: 0.2871 - accuracy: 0.9458 - val_loss: 1.0408 - val_accuracy: 0.5589
# Epoch 11/50
# 107/107 [==============================] - 7s 64ms/step - loss: 0.2560 - accuracy: 0.9512 - val_loss: 1.0411 - val_accuracy: 0.5616
# Epoch 12/50
# 107/107 [==============================] - 7s 62ms/step - loss: 0.2342 - accuracy: 0.9550 - val_loss: 1.0436 - val_accuracy: 0.5625
# Epoch 13/50
# 107/107 [==============================] - 6s 60ms/step - loss: 0.2159 - accuracy: 0.9600 - val_loss: 1.0477 - val_accuracy: 0.5613
# Epoch 14/50
# 107/107 [==============================] - 7s 62ms/step - loss: 0.1949 - accuracy: 0.9642 - val_loss: 1.0498 - val_accuracy: 0.5598
# Epoch 15/50
# 107/107 [==============================] - 7s 63ms/step - loss: 0.1834 - accuracy: 0.9672 - val_loss: 1.0528 - val_accuracy: 0.5630
# Epoch 16/50
# 107/107 [==============================] - 7s 65ms/step - loss: 0.1718 - accuracy: 0.9678 - val_loss: 1.0543 - val_accuracy: 0.5598
# Epoch 17/50
# 107/107 [==============================] - 7s 61ms/step - loss: 0.1589 - accuracy: 0.9715 - val_loss: 1.0564 - val_accuracy: 0.5589

# %% [markdown]
# #### 测试集准确率

# %%
textcnn.evaluate(x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#           求助       0.80      0.77      0.79       244
#         治安案件       0.83      0.76      0.79       225
#           纠纷       0.84      0.93      0.88       568
#           举报       0.83      0.69      0.75        35
#         其它报警       0.59      0.52      0.55       209
#         刑事案件       0.78      0.73      0.76        85
#
#     accuracy                           0.79      1366
#    macro avg       0.78      0.73      0.75      1366
# weighted avg       0.79      0.79      0.79      1366

# %%
textcnn.single_predict("有人聚众打牌") # 单句预测
# Out:
# ('举报', 0.75761837)

# %% [markdown]
# ### (2)调整各个类别的比例

# %%
oversample = SMOTE(sampling_strategy = {0: 1220, 1: 1123, 2:2841 , 3: 1000,4:1200,5:1000})
X, Y = oversample.fit_resample(x, y)
new_y=dict(collections.Counter(Y))
for k in list(new_y):
    new_y[map1[k]] = new_y.pop(k)
pd2=pd.DataFrame.from_dict(new_y, orient='index')
pd2.columns=['数量']
pandas_bokeh.output_notebook()
#在notebook中能显示可视化结果pandas_bokeh.output_notebook()#将fruits列设置为行索引df = pd.read_excel(fruits.xlsx')
pd2.plot_bokeh(kind='bar',
              
              ylabel='案件数量',xlabel='案件类型',
              title='数量',
              show_figure=True) #显示
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1911">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3e9ea0bf-169e-4a19-b3b6-95762dd4c6a8" data-root-id="1948"></div>
# Figure(id='1948', ...)

# %%
x_train,x_valid,y_train, y_valid = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
textcnn2 = TextCNN(config1)
textcnn2.build_model()
# Out:
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 100, 300)     5198700     input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 99, 64)       38464       embedding_4[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 98, 64)       57664       embedding_4[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 97, 64)       76864       embedding_4[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_12 (Global (None, 64)           0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_13 (Global (None, 64)           0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_14 (Global (None, 64)           0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 192)          0           global_max_pooling1d_12[0][0]
#                                                                  global_max_pooling1d_13[0][0]
#                                                                  global_max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 192)          0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           12352       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 6)            390         dense_8[0][0]
# ==================================================================================================
# Total params: 5,384,434
# Trainable params: 5,384,434
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 定义early stop早停回调函数
patience = 5
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)

# 定义checkpoint回调函数
checkpoint_prefix = './clean_checkpoints_smote/textcnn_imdb_ckpt'
checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True,
    save_best_only=True)
textcnn2.fit(x_train, y_train, x_valid, y_valid, epochs=50, callbacks=[early_stop, checkpoint_callback]) # 训练
# Out:
# Epoch 1/50
# 53/53 [==============================] - 3s 63ms/step - loss: 1.4271 - accuracy: 0.4157 - val_loss: 1.0425 - val_accuracy: 0.6649
# Epoch 2/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.8546 - accuracy: 0.7309 - val_loss: 0.7578 - val_accuracy: 0.7519
# Epoch 3/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.6102 - accuracy: 0.8089 - val_loss: 0.6878 - val_accuracy: 0.7549
# Epoch 4/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.4963 - accuracy: 0.8503 - val_loss: 0.6506 - val_accuracy: 0.7651
# Epoch 5/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.4178 - accuracy: 0.8709 - val_loss: 0.6382 - val_accuracy: 0.7651
# Epoch 6/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.3551 - accuracy: 0.8965 - val_loss: 0.6251 - val_accuracy: 0.7680
# Epoch 7/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.3142 - accuracy: 0.9046 - val_loss: 0.6190 - val_accuracy: 0.7680
# Epoch 8/50
# 53/53 [==============================] - 4s 83ms/step - loss: 0.2704 - accuracy: 0.9190 - val_loss: 0.6145 - val_accuracy: 0.7722
# Epoch 9/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.2478 - accuracy: 0.9323 - val_loss: 0.6102 - val_accuracy: 0.7722
# Epoch 10/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.2227 - accuracy: 0.9413 - val_loss: 0.6056 - val_accuracy: 0.7752
# Epoch 11/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.1998 - accuracy: 0.9490 - val_loss: 0.6034 - val_accuracy: 0.7734
# Epoch 12/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.1839 - accuracy: 0.9505 - val_loss: 0.6021 - val_accuracy: 0.7722
# Epoch 13/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.1716 - accuracy: 0.9571 - val_loss: 0.6048 - val_accuracy: 0.7728
# Epoch 14/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.1555 - accuracy: 0.9614 - val_loss: 0.6022 - val_accuracy: 0.7746
# Epoch 15/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.1418 - accuracy: 0.9656 - val_loss: 0.6044 - val_accuracy: 0.7734
# Epoch 16/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.1349 - accuracy: 0.9685 - val_loss: 0.6051 - val_accuracy: 0.7746
# Epoch 17/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.1267 - accuracy: 0.9708 - val_loss: 0.6038 - val_accuracy: 0.7752

# %%
textcnn2.evaluate(x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#           求助       0.83      0.76      0.80       244
#         治安案件       0.85      0.78      0.81       225
#           纠纷       0.85      0.94      0.89       568
#           举报       0.71      0.69      0.70        35
#         其它报警       0.60      0.56      0.58       209
#         刑事案件       0.81      0.75      0.78        85
#
#     accuracy                           0.81      1366
#    macro avg       0.78      0.75      0.76      1366
# weighted avg       0.80      0.81      0.80      1366

# %% [markdown]
# # 使用ADASYN做类似操作

# %% [markdown]
# ### (1)使得6个类别的比例近似为1

# %%
oversample = ADASYN()
X, Y = oversample.fit_resample(x, y)
x_train,x_valid,y_train, y_valid = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
textcnn3 = TextCNN(config1)
textcnn3.build_model()
# 定义early stop早停回调函数
patience = 3
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)

# 定义checkpoint回调函数
checkpoint_prefix = './clean_checkpoints_adasyn/textcnn_imdb_ckpt'
checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True,
    save_best_only=True)


textcnn3.fit(x_train, y_train, x_valid, y_valid, epochs=50, callbacks=[early_stop, checkpoint_callback]) # 训练
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 100, 300)     5198700     input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 99, 64)       38464       embedding_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 98, 64)       57664       embedding_3[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 97, 64)       76864       embedding_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_9 (GlobalM (None, 64)           0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_10 (Global (None, 64)           0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_11 (Global (None, 64)           0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 192)          0           global_max_pooling1d_9[0][0]
#                                                                  global_max_pooling1d_10[0][0]
#                                                                  global_max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 192)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           12352       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 6)            390         dense_6[0][0]
# ==================================================================================================
# Total params: 5,384,434
# Trainable params: 5,384,434
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 108/108 [==============================] - 8s 70ms/step - loss: 1.4908 - accuracy: 0.3994 - val_loss: 1.1672 - val_accuracy: 0.5165
# Epoch 2/50
# 108/108 [==============================] - 7s 63ms/step - loss: 1.0570 - accuracy: 0.6082 - val_loss: 1.0870 - val_accuracy: 0.5354
# Epoch 3/50
# 108/108 [==============================] - 7s 64ms/step - loss: 0.8833 - accuracy: 0.7215 - val_loss: 1.0600 - val_accuracy: 0.5424
# Epoch 4/50
# 108/108 [==============================] - 7s 62ms/step - loss: 0.7484 - accuracy: 0.7922 - val_loss: 1.0519 - val_accuracy: 0.5535
# Epoch 5/50
# 108/108 [==============================] - 7s 61ms/step - loss: 0.6356 - accuracy: 0.8486 - val_loss: 1.0445 - val_accuracy: 0.5520
# Epoch 6/50
# 108/108 [==============================] - 7s 62ms/step - loss: 0.5423 - accuracy: 0.8809 - val_loss: 1.0433 - val_accuracy: 0.5500
# Epoch 7/50
# 108/108 [==============================] - 6s 59ms/step - loss: 0.4759 - accuracy: 0.9021 - val_loss: 1.0438 - val_accuracy: 0.5564
# Epoch 8/50
# 108/108 [==============================] - 6s 59ms/step - loss: 0.4244 - accuracy: 0.9168 - val_loss: 1.0457 - val_accuracy: 0.5541
# Epoch 9/50
# 108/108 [==============================] - 6s 60ms/step - loss: 0.3761 - accuracy: 0.9240 - val_loss: 1.0452 - val_accuracy: 0.5535

# %%
textcnn3.evaluate(x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#           求助       0.82      0.75      0.78       244
#         治安案件       0.81      0.78      0.79       225
#           纠纷       0.85      0.92      0.88       568
#           举报       0.77      0.69      0.73        35
#         其它报警       0.59      0.57      0.58       209
#         刑事案件       0.79      0.68      0.73        85
#
#     accuracy                           0.79      1366
#    macro avg       0.77      0.73      0.75      1366
# weighted avg       0.79      0.79      0.79      1366

# %% [markdown]
# # 使用SMOTEENN进行尝试

# %%
from imblearn.combine import SMOTEENN
smote_enn = SMOTEENN(random_state=0)
X_resampled, y_resampled = smote_enn.fit_resample(x, y)
print(sorted(Counter(y_resampled).items()))
# Out:
# [(0, 1902), (1, 2172), (2, 15), (3, 2841), (4, 2250), (5, 2824)]

# %%
print(sorted(Counter(y).items()))
# Out:
# [(0, 1220), (1, 1123), (2, 2841), (3, 174), (4, 1043), (5, 427)]

# %% [markdown]
# # 使用SMOTETomek进行尝试

# %%
from imblearn.combine import SMOTETomek
smote_tomek = SMOTETomek(random_state=0)
X_resampled, y_resampled = smote_tomek.fit_resample(x, y)
print(sorted(Counter(y_resampled).items()))
# Out:
# [(0, 2837), (1, 2835), (2, 2830), (3, 2841), (4, 2840), (5, 2841)]

# %%
x_train,x_valid,y_train, y_valid = train_test_split(X_resampled,y_resampled, test_size=0.2, random_state=42)

# %%
textcnn4 = TextCNN(config1)
textcnn4.build_model()
# 定义early stop早停回调函数
patience = 3
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)

# 定义checkpoint回调函数
checkpoint_prefix = './clean_checkpoints_SMOTETomek/textcnn_imdb_ckpt'
checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True,
    save_best_only=True)


textcnn4.fit(x_train, y_train, x_valid, y_valid, epochs=50, callbacks=[early_stop, checkpoint_callback]) # 训练
# Out:
# Model: "functional_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 100, 300)     5198700     input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 99, 64)       38464       embedding_5[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 98, 64)       57664       embedding_5[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 97, 64)       76864       embedding_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_15 (Global (None, 64)           0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_16 (Global (None, 64)           0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_17 (Global (None, 64)           0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 192)          0           global_max_pooling1d_15[0][0]
#                                                                  global_max_pooling1d_16[0][0]
#                                                                  global_max_pooling1d_17[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 192)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           12352       dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 6)            390         dense_10[0][0]
# ==================================================================================================
# Total params: 5,384,434
# Trainable params: 5,384,434
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 107/107 [==============================] - 7s 65ms/step - loss: 1.4508 - accuracy: 0.3967 - val_loss: 1.1709 - val_accuracy: 0.5110
# Epoch 2/50
# 107/107 [==============================] - 6s 60ms/step - loss: 1.0429 - accuracy: 0.6138 - val_loss: 1.0783 - val_accuracy: 0.5457
# Epoch 3/50
# 107/107 [==============================] - 6s 60ms/step - loss: 0.8568 - accuracy: 0.7353 - val_loss: 1.0543 - val_accuracy: 0.5486
# Epoch 4/50
# 107/107 [==============================] - 7s 69ms/step - loss: 0.7188 - accuracy: 0.8089 - val_loss: 1.0450 - val_accuracy: 0.5533
# Epoch 5/50
# 107/107 [==============================] - 6s 60ms/step - loss: 0.6060 - accuracy: 0.8571 - val_loss: 1.0373 - val_accuracy: 0.5574
# Epoch 6/50
# 107/107 [==============================] - 6s 59ms/step - loss: 0.5102 - accuracy: 0.8907 - val_loss: 1.0411 - val_accuracy: 0.5612
# Epoch 7/50
# 107/107 [==============================] - 6s 60ms/step - loss: 0.4491 - accuracy: 0.9054 - val_loss: 1.0418 - val_accuracy: 0.5606
# Epoch 8/50
# 107/107 [==============================] - 6s 60ms/step - loss: 0.3885 - accuracy: 0.9201 - val_loss: 1.0473 - val_accuracy: 0.5609

# %%
textcnn4.evaluate(x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#           求助       0.81      0.73      0.77       244
#         治安案件       0.81      0.76      0.78       225
#           纠纷       0.84      0.92      0.88       568
#           举报       0.80      0.69      0.74        35
#         其它报警       0.57      0.55      0.56       209
#         刑事案件       0.78      0.69      0.73        85
#
#     accuracy                           0.78      1366
#    macro avg       0.77      0.72      0.74      1366
# weighted avg       0.78      0.78      0.78      1366
